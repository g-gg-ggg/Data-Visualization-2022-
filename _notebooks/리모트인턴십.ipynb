# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns

from plotnine import *

# %%
df = pd.read_csv("경기도 수원시_지역화폐 결제 정보_20201211.csv",  encoding='euc-kr', sep=',' )
df.head()
# Out:
#       기준년월 시군구명 읍면동명 성별  연령대    업종명  결제건수     결제금액     데이터기준일자
# 0  2020-11  권선구  고색동  남  10대   레져업소    20   106900  2020-12-11
# 1  2020-11  권선구  고색동  남  10대   보건위생     3    29000  2020-12-11
# 2  2020-11  권선구  고색동  남  10대   서적문구     1     5600  2020-12-11
# 3  2020-11  권선구  고색동  남  10대     약국     1    13600  2020-12-11
# 4  2020-11  권선구  고색동  남  10대  유통업영리    70  2160910  2020-12-11

# %%
df.columns
# Out:
# Index(['기준년월', '시군구명', '읍면동명', '성별', '연령대', '업종명', '결제건수', '결제금액', '데이터기준일자'], dtype='object')

# %%
df.isna().sum()
# Out:
# 기준년월       0
# 시군구명       0
# 읍면동명       0
# 성별         0
# 연령대        0
# 업종명        0
# 결제건수       0
# 결제금액       0
# 데이터기준일자    0
# dtype: int64

# %%
df.groupby(by = ["성별", "연령대"]).mean()
# Out:
#                 결제건수          결제금액
# 성별 연령대
# 남  10대     20.609705  3.346160e+05
#    10세미만    3.664336  5.366762e+04
#    20대    128.655133  1.847284e+06
#    30대     90.442069  1.785991e+06
#    40대    110.542154  2.583102e+06
#    50대     80.686552  1.603525e+06
#    60대이상   41.747868  8.210617e+05
# 여  10대     19.126761  3.634044e+05
#    10세미만    3.339181  5.913301e+04
#    20대    116.476430  1.957207e+06
#    30대    102.278495  2.245574e+06
#    40대    133.528537  3.038024e+06
#    50대     78.882338  1.506639e+06
#    60대이상   39.301196  7.581883e+05

# %%
df[df["기준년월"] == 11]
# Out:
# Empty DataFrame
# Columns: [기준년월, 시군구명, 읍면동명, 성별, 연령대, 업종명, 결제건수, 결제금액, 데이터기준일자]
# Index: []

# %%
df.groupby(by = ["기준년월"]).sum()
# Out:
#             결제건수         결제금액
# 기준년월
# 2019-04     7533    145854678
# 2019-05   122174   2020002695
# 2019-06   151319   2321087040
# 2019-07   167903   2739550377
# 2019-08   202946   3281453945
# 2019-09   136300   2438201912
# 2019-10   188366   3364018252
# 2019-11   192324   3241064404
# 2019-12   198873   3683393449
# 2020-01   210639   3792497510
# 2020-02   169746   3071089666
# 2020-03   262777   4661766253
# 2020-04   843203  17384756045
# 2020-05  1949378  38648289444
# 2020-06  1412659  27787404703
# 2020-07  1202350  23010403011
# 2020-08   895751  16924749224
# 2020-09  1080108  22056120549
# 2020-10  1229284  24909282874
# 2020-11  1190817  25671101354

# %%
sns.lineplot(data = df, x ="기준년월", y = "결제건수")
# Out:
# <AxesSubplot:xlabel='기준년월', ylabel='결제건수'>
# /Users/heji/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
# /Users/heji/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
# /Users/heji/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
# /Users/heji/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
# /Users/heji/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44208 (\N{HANGUL SYLLABLE GYEOL}) missing from current font.
# ...
