# %% [markdown]
# # 데이터 시각화3
# >fig, axes
# - categories: [python]

# %% [markdown]
# ## 문제1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, axs = plt.subplots(2, 3)

# %%
x,y = [1,2,3,4], [1,2,4,3] 

axs[0,0].plot(x, y,'or')
axs[1,0].plot(x, y,'--or')
axs[0,1].plot(x, y,'og')
axs[1,1].plot(x, y,'--og')
axs[0,2].plot(x, y,'ob')
axs[1,2].plot(x, y,'--ob')

fig

# %% [markdown]
# ## 문제2

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.5,0.5,1,1])  
ax2 = fig.add_axes([1.0,1.0,1,1])
ax3 = fig.add_axes([1.5,1.5,1,1])

ax1,ax2,ax3 = fig.axes

fig.axes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 fig = plt.figure()
#       2 ax1 = fig.add_axes([0.5,0.5,1,1])
#       3 ax2 = fig.add_axes([1.0,1.0,1,1])
#
# NameError: name 'plt' is not defined

# %%
x,y = [1,2,3,4], [1,2,1,1]
ax1.plot(x, y, "or")
ax2.plot(x, y, "og")
ax3.plot(x, y, "ob")

fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 x,y = [1,2,3,4], [1,2,1,1]
# ----> 2 ax1.plot(x, y, "or")
#       3 ax2.plot(x, y, "og")
#       4 ax3.plot(x, y, "ob")
#
# NameError: name 'ax1' is not defined

# %% [markdown]
# ## 문제 3

# %%
x = np.arange(-5,5,0.1)
y1 = np.sin(x)
y2 = np.sin(2*x) + 2
y3 = np.sin(4*x) + 4 
y4 = np.sin(8*x) + 6

# %%
plt.plot(x, y1, "--r")
plt.plot(x, y2, "--g")
plt.plot(x, y3, "--b")
plt.plot(x, y4, "--m")
