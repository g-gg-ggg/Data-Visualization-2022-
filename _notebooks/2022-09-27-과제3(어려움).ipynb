# %% [markdown]
# # 데이터 시각화 과제
# >무상관과 독립
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: 김혜지
# - categories: [python]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
np.random.seed(43052)
ϵ = np.random.randn(100)

# %%
plt.plot(np.arange(1,101),ϵ,'--o')

# %% [markdown]
# (1) $\epsilon_t$ 와 $\epsilon_{t-1}$은 독립이라고 보여지는가?

# %% [markdown]
# 독립이다.

# %% [markdown]
# (2) 아래의 수식을 만족하는 벡터 ${\boldsymbol y} = (y_1,y_2,\dots, y_{100})$ 을 생성하라. (단 $y_1=\epsilon_1$)
#
# $$ y_t = y_{t-1} + \epsilon_t$$

# %%
y = np.cumsum(ϵ) #y는 입실론을 다 더한 것

# %%
plt.plot(y,'--o')

# %% [markdown]
# (3) $(t,y_t)$의 dot-connected plot을 그려라.

# %% [markdown]
# (4) $y_t$와 $y_{t-1}$은 독립이라고 볼 수 있는가?

# %% [markdown]
# $y_{t-1}$이 변할때 $y_t$가 변하기에 독립이라고 볼 수 없다
