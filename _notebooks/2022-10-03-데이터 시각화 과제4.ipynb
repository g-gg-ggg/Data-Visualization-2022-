# %% [markdown]
# # 데이터 시각화 과제 4
# > seaborn
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: 김혜지
# - categories: [python]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **아래의 그림에 대응하는 그림을 seaborn을 이용하여 그려라**

# %%
y1 = np.random.randn(90).cumsum() 
y2 = np.random.randn(120).cumsum()

# %%
plt.plot(y1,'--o')
plt.plot(y2,'--o')

# %%
df = pd.DataFrame({'index' : list(range(90))+list(range(120)), 'val' : np.concatenate([y1,y2]), 'cat' : ["y1"]*90+["y2"]*120})

# %%
df
# Out:
#      index       val cat
# 0        0  0.512007  y1
# 1        1  0.836565  y1
# 2        2  1.040704  y1
# 3        3  1.397047  y1
# 4        4  0.765464  y1
# ..     ...       ...  ..
# 205    115 -8.820426  y2
# 206    116 -9.655268  y2
# 207    117 -9.507072  y2
# 208    118 -7.630993  y2
# 209    119 -7.234471  y2
#
# [210 rows x 3 columns]

# %%
sns.lineplot(data = df, x = "index", y= "val", hue = "cat")
# Out:
# <AxesSubplot:xlabel='index', ylabel='val'>

# %%
sns.lineplot(data = df, x ="index", y = "val", style = "cat", hue = "cat", dashes = [(5,1),(9,3)], markers = ['o','o'], markersize = 9)
# Out:
# <AxesSubplot:xlabel='index', ylabel='val'>
